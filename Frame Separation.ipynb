# %%
# Importing all necessary libraries 
import cv2 
import os 
  
# Read the video from specified path 
cam = cv2.VideoCapture("C:/Users/MUNEESWARI S/Desktop/Sample Input and Output-Detecting Moving Objects/Background Subtractions/Background Subtraction MOG2/Output Video/Background output 1.mp4") 
  
try: 
      
    # creating a folder named data 
    if not os.path.exists('Backgroundframe'): 
        os.makedirs('Backgroundframe') 
  
# if not created then raise error 
except OSError: 
    print ('Error: Creating directory of data') 
  
# frame 
currentframe = 0
  
while(True): 
      
    # reading from frame 
    ret,frame = cam.read() 
  
    if ret: 
        # if video is still left continue creating images 
        name = './Backgroundframe/frame' + str(currentframe) + '.jpg'
        print ('Creating...' + name) 
  
        # writing the extracted images 
        cv2.imwrite(name, frame) 
  
        # increasing counter so that it will 
        # show how many frames are created 
        currentframe += 1
    else: 
        break
  
# Release all space and windows once done 
cam.release() 
cv2.destroyAllWindows()
# Out:
# Creating..../Backgroundframe/frame0.jpg
# Creating..../Backgroundframe/frame1.jpg
# Creating..../Backgroundframe/frame2.jpg
# Creating..../Backgroundframe/frame3.jpg
# Creating..../Backgroundframe/frame4.jpg
# Creating..../Backgroundframe/frame5.jpg
# Creating..../Backgroundframe/frame6.jpg
# Creating..../Backgroundframe/frame7.jpg
# Creating..../Backgroundframe/frame8.jpg
# Creating..../Backgroundframe/frame9.jpg
# Creating..../Backgroundframe/frame10.jpg
# Creating..../Backgroundframe/frame11.jpg
# Creating..../Backgroundframe/frame12.jpg
# Creating..../Backgroundframe/frame13.jpg
# Creating..../Backgroundframe/frame14.jpg
# Creating..../Backgroundframe/frame15.jpg
# Creating..../Backgroundframe/frame16.jpg
# Creating..../Backgroundframe/frame17.jpg
# Creating..../Backgroundframe/frame18.jpg
# Creating..../Backgroundframe/frame19.jpg
# Creating..../Backgroundframe/frame20.jpg
# Creating..../Backgroundframe/frame21.jpg
# Creating..../Backgroundframe/frame22.jpg
# ...
